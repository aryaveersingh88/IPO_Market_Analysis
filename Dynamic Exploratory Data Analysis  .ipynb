# %% [markdown]
# # Exploratory Data Analysis

# %%
import re 
import datetime
import pandas as pd
import numpy as np
import os
import scipy

# %% [markdown]
# ### Step 1: Loading the Data file and creating an empty Pattern Matrix

# %%
#Data load
df_2016 = pd.read_csv('C:\\Users\\asingh368\\Desktop\\outlier Analysis\\Data\\2016_Data.csv', sep = ',', dtype='str')

#Empty Pattern Matrix 
df_pattern_matrix = pd.DataFrame(index=df_2016.index,columns=list(df_2016.columns))

# %% [markdown]
# ### Step2 : Basic cleaning of Data:- Fill null values with a NaN(not a number) string

# %%
df_2016 = df_2016.fillna('NaN')

# %% [markdown]
# ### Step3 : Creating a global level Monetary Pattern lookup list. Regular expressions are used to identify the pattern
# ### for e.g.
# ### 17 is represented  '\d*'
# ### 17.08 is represented '\d*\.\d{2}'

# %%
monetary_lookups = [
     ('^\d*$','Monetary_Pat1'),
     ('^\d*\.\d{2}$','Monetary_Pat2'),
     ('^\$\d*$','Monetary_Pat3'),
     ('^\$\d*\.\d*$','Monetary_Pat4'),
     ('^\$\d*\.\d*$','Monetary_Pat5'),
     ('^\$\d*\.\d{2}$','Monetary_Pat6')
]

# %% [markdown]
# ### Step4 : Function to identify the Pattern in a given column
# ### parameters provided to the function are
# ### 1. Name of Dataframe (python equivalent of a Data Table)
# ### 2. Lookup list defined above
# ### 3. Column name from the file starting for first column

# %%
def lookup(s,lookinto,colname):
    compiled_pattern=''
    defcol = s[colname]
         
    for pattern, value in lookinto:
        compiled_pattern = re.compile(str(pattern))
                
        
        if bool(compiled_pattern.match(defcol)):
            return value

# %% [markdown]
# ### Step5 : Extract the column names and values from the DataFrame
# ### Run a loop and call the above mentioned function for each column
# ##### As we execute the function for each column we are providing pattern information to the corresponding cell in pattern Matrix
# #####  Note : Pattern Matrix and Data Structure are identical in structure

# %%
for name, values in df_2016.items():
    df_pattern_matrix[name] = df_2016.apply(lookup,axis =1, lookinto = monetary_lookups , colname =name)

# %% [markdown]
# ### Preview Data from the file

# %%
df_2016.head()
# Out:
#   EmployeeIDNumber Name Gender      USC AccruedBenefit1   BirthDate  \
# 0             1160  NaN      F  RetBene               0   5/17/1950
# 1             1301  NaN      M  DefBene               0   11/8/1952
# 2             1937  NaN      M  RetBene               0   2/28/1944
# 3             2978  NaN      M  DefBene               0  10/23/1953
# 4             3297  NaN      F  DefBene               0   9/24/1953
#
#    HireDate1 MembershipDate1 StartDate1 LumpSumDeathBenefit1   ...    \
# 0  6/12/1980             NaN   1/1/2013                    0   ...
# 1  6/12/1980             NaN   9/1/2021                    0   ...
# 2  6/12/1980             NaN   7/1/2005                    0   ...
# 3  6/12/1980             NaN   9/1/2022                    0   ...
# 4  6/12/1980             NaN   8/1/2014                    0   ...
#
#   Benefit1DB Beneficiary1Percent1 PaymentForm1 Beneficiary1BirthDate  \
# 0    2123.28                  100          J&S              3/1/1950
# 1    4618.44                  100          J&S             8/23/1952
# 2    2860.80                  100          J&S            12/13/1943
# 3    2680.08                  100          J&S              8/7/1953
# 4    6117.43                  100          J&S              7/9/1953
#
#   Beneficiary1Gender YearsCertain1 ChangeDate1    USC_P     Salary    Plan
# 0                  F           NaN         NaN  RetBene   64000.00  Plan A
# 1                  M           NaN    9/1/2021  DefBene  116000.99  Plan A
# 2                  M           NaN         NaN  RetBene   93000.00  Plan A
# 3                  M           NaN    9/1/2022  DefBene   59000.00  Plan A
# 4                  F           NaN    8/1/2014  DefBene   68000.00  Plan B
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Preview of the Pattern Matrix

# %%
df_pattern_matrix.head()
# Out:
#   EmployeeIDNumber  Name Gender   USC AccruedBenefit1 BirthDate HireDate1  \
# 0    Monetary_Pat1  None   None  None   Monetary_Pat1      None      None
# 1    Monetary_Pat1  None   None  None   Monetary_Pat1      None      None
# 2    Monetary_Pat1  None   None  None   Monetary_Pat1      None      None
# 3    Monetary_Pat1  None   None  None   Monetary_Pat1      None      None
# 4    Monetary_Pat1  None   None  None   Monetary_Pat1      None      None
#
#   MembershipDate1 StartDate1 LumpSumDeathBenefit1  ...      Benefit1DB  \
# 0            None       None        Monetary_Pat1  ...   Monetary_Pat2
# 1            None       None        Monetary_Pat1  ...   Monetary_Pat2
# 2            None       None        Monetary_Pat1  ...   Monetary_Pat2
# 3            None       None        Monetary_Pat1  ...   Monetary_Pat2
# 4            None       None        Monetary_Pat1  ...   Monetary_Pat2
#
#   Beneficiary1Percent1 PaymentForm1 Beneficiary1BirthDate Beneficiary1Gender  \
# 0        Monetary_Pat1         None                  None               None
# 1        Monetary_Pat1         None                  None               None
# 2        Monetary_Pat1         None                  None               None
# 3        Monetary_Pat1         None                  None               None
# 4        Monetary_Pat1         None                  None               None
#
#   YearsCertain1 ChangeDate1 USC_P         Salary  Plan
# 0          None        None  None  Monetary_Pat2  None
# 1          None        None  None  Monetary_Pat2  None
# 2          None        None  None  Monetary_Pat2  None
# 3          None        None  None  Monetary_Pat2  None
# 4          None        None  None  Monetary_Pat2  None
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Step6 : Finding Categorical columns in the Data
# ### e.g. Product codes, Gender, Plans, rider
# ### Basic cleaning steps on Pattern Matrix to fill Null values

# %%
df_pattern_matrix = df_pattern_matrix.fillna('NaN')
df_pattern_matrix.head()
# Out:
#   EmployeeIDNumber Name Gender  USC AccruedBenefit1 BirthDate HireDate1  \
# 0    Monetary_Pat1  NaN    NaN  NaN   Monetary_Pat1       NaN       NaN
# 1    Monetary_Pat1  NaN    NaN  NaN   Monetary_Pat1       NaN       NaN
# 2    Monetary_Pat1  NaN    NaN  NaN   Monetary_Pat1       NaN       NaN
# 3    Monetary_Pat1  NaN    NaN  NaN   Monetary_Pat1       NaN       NaN
# 4    Monetary_Pat1  NaN    NaN  NaN   Monetary_Pat1       NaN       NaN
#
#   MembershipDate1 StartDate1 LumpSumDeathBenefit1 ...      Benefit1DB  \
# 0             NaN        NaN        Monetary_Pat1 ...   Monetary_Pat2
# 1             NaN        NaN        Monetary_Pat1 ...   Monetary_Pat2
# 2             NaN        NaN        Monetary_Pat1 ...   Monetary_Pat2
# 3             NaN        NaN        Monetary_Pat1 ...   Monetary_Pat2
# 4             NaN        NaN        Monetary_Pat1 ...   Monetary_Pat2
#
#   Beneficiary1Percent1 PaymentForm1 Beneficiary1BirthDate Beneficiary1Gender  \
# 0        Monetary_Pat1          NaN                   NaN                NaN
# 1        Monetary_Pat1          NaN                   NaN                NaN
# 2        Monetary_Pat1          NaN                   NaN                NaN
# 3        Monetary_Pat1          NaN                   NaN                NaN
# 4        Monetary_Pat1          NaN                   NaN                NaN
#
#   YearsCertain1 ChangeDate1 USC_P         Salary Plan
# 0           NaN         NaN   NaN  Monetary_Pat2  NaN
# 1           NaN         NaN   NaN  Monetary_Pat2  NaN
# 2           NaN         NaN   NaN  Monetary_Pat2  NaN
# 3           NaN         NaN   NaN  Monetary_Pat2  NaN
# 4           NaN         NaN   NaN  Monetary_Pat2  NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Function to identify Categorical Columns
# #### Doesn't have large number of unique values in comparison to the total dataset population

# %%
for a, b in df_2016.items():
    
    df_unique_patterns = df_pattern_matrix[a].unique()
    df_unique_patterns_list = df_unique_patterns.tolist()
    
    df_data_patterns = df_2016[a].unique()
    df_data_patterns_count = len(df_data_patterns)
    
    
    matrix_pattern_list = "".join(df_unique_patterns_list)
    
    
    if ('Monetary' not in matrix_pattern_list):
        if (df_data_patterns_count < 20) & (df_data_patterns_count > 1) :
            df_pattern_matrix.loc[:,a] = 'Categorical'

# %%
df_pattern_matrix.head()
# Out:
#   EmployeeIDNumber Name       Gender          USC AccruedBenefit1 BirthDate  \
# 0    Monetary_Pat1  NaN  Categorical  Categorical   Monetary_Pat1       NaN
# 1    Monetary_Pat1  NaN  Categorical  Categorical   Monetary_Pat1       NaN
# 2    Monetary_Pat1  NaN  Categorical  Categorical   Monetary_Pat1       NaN
# 3    Monetary_Pat1  NaN  Categorical  Categorical   Monetary_Pat1       NaN
# 4    Monetary_Pat1  NaN  Categorical  Categorical   Monetary_Pat1       NaN
#
#   HireDate1 MembershipDate1 StartDate1 LumpSumDeathBenefit1     ...       \
# 0       NaN             NaN        NaN        Monetary_Pat1     ...
# 1       NaN             NaN        NaN        Monetary_Pat1     ...
# 2       NaN             NaN        NaN        Monetary_Pat1     ...
# 3       NaN             NaN        NaN        Monetary_Pat1     ...
# 4       NaN             NaN        NaN        Monetary_Pat1     ...
#
#       Benefit1DB Beneficiary1Percent1 PaymentForm1 Beneficiary1BirthDate  \
# 0  Monetary_Pat2        Monetary_Pat1  Categorical                   NaN
# 1  Monetary_Pat2        Monetary_Pat1  Categorical                   NaN
# 2  Monetary_Pat2        Monetary_Pat1  Categorical                   NaN
# 3  Monetary_Pat2        Monetary_Pat1  Categorical                   NaN
# 4  Monetary_Pat2        Monetary_Pat1  Categorical                   NaN
#
#   Beneficiary1Gender YearsCertain1 ChangeDate1        USC_P         Salary  \
# 0        Categorical           NaN         NaN  Categorical  Monetary_Pat2
# 1        Categorical           NaN         NaN  Categorical  Monetary_Pat2
# 2        Categorical           NaN         NaN  Categorical  Monetary_Pat2
# 3        Categorical           NaN         NaN  Categorical  Monetary_Pat2
# 4        Categorical           NaN         NaN  Categorical  Monetary_Pat2
#
#           Plan
# 0  Categorical
# 1  Categorical
# 2  Categorical
# 3  Categorical
# 4  Categorical
#
# [5 rows x 25 columns]

# %%
df_2016.head()
# Out:
#   EmployeeIDNumber Name Gender      USC AccruedBenefit1   BirthDate  \
# 0             1160  NaN      F  RetBene               0   5/17/1950
# 1             1301  NaN      M  DefBene               0   11/8/1952
# 2             1937  NaN      M  RetBene               0   2/28/1944
# 3             2978  NaN      M  DefBene               0  10/23/1953
# 4             3297  NaN      F  DefBene               0   9/24/1953
#
#    HireDate1 MembershipDate1 StartDate1 LumpSumDeathBenefit1   ...    \
# 0  6/12/1980             NaN   1/1/2013                    0   ...
# 1  6/12/1980             NaN   9/1/2021                    0   ...
# 2  6/12/1980             NaN   7/1/2005                    0   ...
# 3  6/12/1980             NaN   9/1/2022                    0   ...
# 4  6/12/1980             NaN   8/1/2014                    0   ...
#
#   Benefit1DB Beneficiary1Percent1 PaymentForm1 Beneficiary1BirthDate  \
# 0    2123.28                  100          J&S              3/1/1950
# 1    4618.44                  100          J&S             8/23/1952
# 2    2860.80                  100          J&S            12/13/1943
# 3    2680.08                  100          J&S              8/7/1953
# 4    6117.43                  100          J&S              7/9/1953
#
#   Beneficiary1Gender YearsCertain1 ChangeDate1    USC_P     Salary    Plan
# 0                  F           NaN         NaN  RetBene   64000.00  Plan A
# 1                  M           NaN    9/1/2021  DefBene  116000.99  Plan A
# 2                  M           NaN         NaN  RetBene   93000.00  Plan A
# 3                  M           NaN    9/1/2022  DefBene   59000.00  Plan A
# 4                  F           NaN    8/1/2014  DefBene   68000.00  Plan B
#
# [5 rows x 25 columns]

# %%
del [a,b]
for a,b in df_pattern_matrix.items():
    
    print('==========================================================================================================')
    
    df_unique_patterns = df_pattern_matrix[a].unique()
    df_unique_patterns_list = df_unique_patterns.tolist()
    
    df_data_patterns = df_2016[a].unique()
    df_data_patterns_count = len(df_data_patterns)
    
    print('Patterns detected in the column :' +str(df_unique_patterns_list))
    print('Number of Unique values in the data column :' +str(df_data_patterns_count))
# Out:
# ==========================================================================================================
# Patterns detected in the column :['Monetary_Pat1']
# Number of Unique values in the data column :3838
# ==========================================================================================================
# Patterns detected in the column :['NaN']
# Number of Unique values in the data column :1
# ==========================================================================================================
# Patterns detected in the column :['Categorical']
# Number of Unique values in the data column :2
# ==========================================================================================================
# Patterns detected in the column :['Categorical']
# Number of Unique values in the data column :8
# ==========================================================================================================
# Patterns detected in the column :['Monetary_Pat1', 'NaN']
# Number of Unique values in the data column :1385
# ==========================================================================================================
# Patterns detected in the column :['NaN']
# Number of Unique values in the data column :3403
# ==========================================================================================================
# Patterns detected in the column :['NaN']
# Number of Unique values in the data column :2115
# ==========================================================================================================
# Patterns detected in the column :['NaN']
# Number of Unique values in the data column :90
# ==========================================================================================================
# Patterns detected in the column :['NaN']
# Number of Unique values in the data column :677
# ==========================================================================================================
# Patterns detected in the column :['Monetary_Pat1', 'NaN']
# Number of Unique values in the data column :4
# ==========================================================================================================
# Patterns detected in the column :['NaN', 'Monetary_Pat1']
# Number of Unique values in the data column :52
# ==========================================================================================================
# Patterns detected in the column :['NaN', 'Monetary_Pat1']
# Number of Unique values in the data column :51
# ==========================================================================================================
# Patterns detected in the column :['NaN', 'Monetary_Pat2', 'Monetary_Pat1']
# Number of Unique values in the data column :961
# ==========================================================================================================
# Patterns detected in the column :['Categorical']
# Number of Unique values in the data column :3
# ==========================================================================================================
# Patterns detected in the column :['Categorical']
# Number of Unique values in the data column :2
# ==========================================================================================================
# Patterns detected in the column :['Monetary_Pat2']
# Number of Unique values in the data column :2799
# ==========================================================================================================
# Patterns detected in the column :['Monetary_Pat1', 'NaN']
# Number of Unique values in the data column :5
# ==========================================================================================================
# Patterns detected in the column :['Categorical']
# Number of Unique values in the data column :3
# ==========================================================================================================
# Patterns detected in the column :['NaN']
# Number of Unique values in the data column :541
# ==========================================================================================================
# Patterns detected in the column :['Categorical']
# Number of Unique values in the data column :3
# ==========================================================================================================
# Patterns detected in the column :['NaN', 'Monetary_Pat1']
# Number of Unique values in the data column :5
# ==========================================================================================================
# Patterns detected in the column :['NaN']
# Number of Unique values in the data column :398
# ==========================================================================================================
# Patterns detected in the column :['Categorical']
# Number of Unique values in the data column :9
# ==========================================================================================================
# Patterns detected in the column :['Monetary_Pat2']
# Number of Unique values in the data column :67
# ==========================================================================================================
# Patterns detected in the column :['Categorical']
# Number of Unique values in the data column :3

# %% [markdown]
# ## Next Steps :-
# ### 1. Implement ReGex patterns for dates - Identical to Monetary values using Dates Lookup lists
# ###     a. Adding simillar lookup lists for other columns like dimensions & non-cdm columns
# ### 2. Display Statistics based on data observed from Pattern Matrix (Number of columns, number of categorical columns & values)
# ### 3. Report rules engine - based on task2  statistics recommends Data clean up tasks in the report (Excel or Database parsing)
# ### 4. Embed graphs in the reports to display the spread of the data
# ### 5. Scale the code to ingest multiple files from multiple formats and produce a consolidated report
# ###       a. Reading excel tab and compiling them into a system readable file format.
